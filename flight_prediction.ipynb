# %%
#importing Libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)

# %%
df=pd.read_excel("C:\\Users\\91865\\FlipRobo\\flight_prediction.xlsx")
df
# Out:
#      Unnamed: 0 Airline Name  Departure Time  Arrival Time  Stop   Time  Price
# 0             1      Vistara           16.00         18.20     0   2.20   8568
# 1             2     AirIndia            6.00          8.05     0   2.05   8566
# 2             3        Goair           19.45         21.50     0   2.05   8566
# 3             4       Indigo            8.05         10.15     0   2.10   8566
# 4             5      AirAsia           12.10         14.20     0   2.10   8566
# 5             6      AirAsia           21.15         23.30     0   2.15   8566
# 6             7      AirAsia           23.00          1.10     0   2.10   8566
# 7             8      AirAsia           20.40         22.55     0   2.15   8566
# 8             9      AirAsia           15.25         23.10     1   7.45   8499
# 9            10      AirAsia            6.35         22.00     1   1.30   8702
# 10           11     AirIndia           22.35         22.00     1   1.30   8702
# ...

# %%
#dropping unnaed column form the df
df=df.drop(columns=['Unnamed: 0'])
df
# Out:
#     Airline Name  Departure Time  Arrival Time  Stop   Time  Price
# 0        Vistara           16.00         18.20     0   2.20   8568
# 1       AirIndia            6.00          8.05     0   2.05   8566
# 2          Goair           19.45         21.50     0   2.05   8566
# 3         Indigo            8.05         10.15     0   2.10   8566
# 4        AirAsia           12.10         14.20     0   2.10   8566
# 5        AirAsia           21.15         23.30     0   2.15   8566
# 6        AirAsia           23.00          1.10     0   2.10   8566
# 7        AirAsia           20.40         22.55     0   2.15   8566
# 8        AirAsia           15.25         23.10     1   7.45   8499
# 9        AirAsia            6.35         22.00     1   1.30   8702
# 10      AirIndia           22.35         22.00     1   1.30   8702
# 11      AirIndia            6.35          8.20     1   1.35   8702
# 12      AirIndia           20.00          8.20     1   1.35   8702
# ...

# %%
#column name
df.columns
# Out:
# Index(['Airline Name', 'Departure Time', 'Arrival Time', 'Stop', 'Time',
#        'Price'],
#       dtype='object')

# %%
#check all the information that carries this dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Airline Name    244 non-null    object
#  1   Departure Time  244 non-null    float64
#  2   Arrival Time    244 non-null    float64
#  3   Stop            244 non-null    int64
#  4   Time            244 non-null    float64
#  5   Price           244 non-null    int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 11.6+ KB

# %%
#shape of the dataset
df.shape
# Out:
# (244, 6)

# %%
#check the null values 
df.isna().sum()
# Out:
# Airline Name      0
# Departure Time    0
# Arrival Time      0
# Stop              0
# Time              0
# Price             0
# dtype: int64

# %%
#description of dataset
df.describe()
# Out:
#        Departure Time  Arrival Time        Stop        Time         Price
# count      244.000000    244.000000  244.000000  244.000000    244.000000
# mean        13.109016     15.795697    0.848361   10.870697  14543.045082
# std          5.512201      6.026817    0.381622    7.594472   4900.125802
# min          0.350000      0.050000    0.000000    1.300000   8499.000000
# 25%          7.500000     10.537500    1.000000    4.537500   8568.000000
# 50%         12.275000     17.025000    1.000000    9.400000  15423.500000
# 75%         18.150000     21.100000    1.000000   15.425000  17596.500000
# max         23.300000     23.550000    2.000000   30.000000  28550.000000

# %%
#check the correlation between columns
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,annot_kws={"size":8})
plt.show()

# %% [markdown]
# Nothing is correlation with each other in columns so we dont need to delete or drop anything to ignore biasedness or anything to build model on this adatset

# %%
df['Airline Name']=df['Airline Name'].replace({"AirAsia":0,'AirIndia':1,'Indigo':2,"Goair":3,'Spicejet':4,'Vistara':5})
df
# Out:
#      Airline Name  Departure Time  Arrival Time  Stop   Time  Price
# 0               5           16.00         18.20     0   2.20   8568
# 1               1            6.00          8.05     0   2.05   8566
# 2               3           19.45         21.50     0   2.05   8566
# 3               2            8.05         10.15     0   2.10   8566
# 4               0           12.10         14.20     0   2.10   8566
# 5               0           21.15         23.30     0   2.15   8566
# 6               0           23.00          1.10     0   2.10   8566
# 7               0           20.40         22.55     0   2.15   8566
# 8               0           15.25         23.10     1   7.45   8499
# 9               0            6.35         22.00     1   1.30   8702
# 10              1           22.35         22.00     1   1.30   8702
# 11              1            6.35          8.20     1   1.35   8702
# 12              1           20.00          8.20     1   1.35   8702
# ...

# %%
#lets check the data distribution for every column
plt.figure(figsize=(10,10))
plotnumber=1
for column in df:
    if plotnumber<=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\91865\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\91865\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# all are almost normally distribution datset

# %%
#lets check the skewness of dataset
df.skew()
# Out:
# Airline Name     -0.121002
# Departure Time    0.106131
# Arrival Time     -0.693442
# Stop             -1.496863
# Time              0.689318
# Price             0.324820
# dtype: float64

# %% [markdown]
# skewness is not that so we can cope up with this by not deleting any of the datset

# %%
#now split the dataset into label and features
x=df.drop(columns=['Price'])
y=df['Price']

# %%
print(x)
print(y)
# Out:
#      Airline Name  Departure Time  Arrival Time  Stop   Time
# 0               5           16.00         18.20     0   2.20
# 1               1            6.00          8.05     0   2.05
# 2               3           19.45         21.50     0   2.05
# 3               2            8.05         10.15     0   2.10
# 4               0           12.10         14.20     0   2.10
# 5               0           21.15         23.30     0   2.15
# 6               0           23.00          1.10     0   2.10
# 7               0           20.40         22.55     0   2.15
# 8               0           15.25         23.10     1   7.45
# 9               0            6.35         22.00     1   1.30
# 10              1           22.35         22.00     1   1.30
# 11              1            6.35          8.20     1   1.35
# 12              1           20.00          8.20     1   1.35
# 13              1           22.35          8.20     1   1.35
# ...

# %%
#shape of x and y
print("Shape of x : ",x.shape)
print("Shape of y :",y.shape)
# Out:
# Shape of x :  (244, 5)
# Shape of y : (244,)

# %%
plt.figure(figsize=(10,10))
plotnumber=1
for column in x:
    if plotnumber<=10:
        ax=plt.subplot(2,3,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column)
        plt.ylabel('Price')
    plotnumber+=1
plt.show()

# %% [markdown]
# all are equallt matters to build an model so all the feature is provided something to build predictable model

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaled_x=scaler.fit_transform(x)

# %%
scaled_x
# Out:
# array([[ 1.25435268,  0.52554794,  0.39975419, -2.22761008, -1.14405843],
#        [-0.99197432, -1.29233833, -1.28784698, -2.22761008, -1.16385024],
#        [ 0.13118918,  1.1527187 ,  0.9484324 , -2.22761008, -1.16385024],
#        ...,
#        [-1.55355607,  1.27088131,  0.4163808 ,  0.39817185,  1.4948493 ],
#        [-0.99197432, -0.74697245,  0.61590015,  0.39817185, -0.04891172],
#        [-1.55355607, -1.4286798 ,  0.61590015,  0.39817185,  0.43928621]])

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(scaled_x,y,test_size=0.25,random_state=0)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (183, 5)
# (183,)
# (61, 5)
# (61,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#model accuracy on training dataset
lr.score(x_train,y_train)
# Out:
# 0.42370137362861926

# %%
y_pred_lr=lr.predict(x_test)

# %%
y_pred_lr
# Out:
# array([13927.66480341, 13034.79165484, 11698.72161504, 13568.63109947,
#        16410.31774667, 12256.29662557, 10537.13234082, 12793.00241994,
#        20665.14903991, 15838.24029145, 15193.19468499, 20064.25798359,
#        14830.31978191, 15159.040508  , 17434.22580896,  7696.35148292,
#        13161.35215413, 12738.74694123, 18248.29703393, 21482.00826843,
#        14356.19290362, 12979.94212216, 18207.9488531 , 15323.98762074,
#        16419.72712785, 16355.71966167, 17788.25775886, 15953.59044788,
#         9873.81937169,  9235.74851254,  9670.50096531, 17602.67391403,
#        11823.54044018, 19716.3697908 ,  9594.65884009, 15024.98268361,
#         9998.11704493, 21597.17705023, 15714.69518869, 14165.67225217,
#        14822.43706958, 12700.21104426, 13878.00309431, 17258.87771852,
#        19026.66000088,  8658.88472456, 19816.68035335, 10148.68531611,
#        16056.20604683,  9911.9381242 , 17725.34677547, 14141.37626056,
# ...

# %%
lr.score(x_test,y_test)
# Out:
# 0.29086117805506995

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred_lr)
# Out:
# 0.29086117805506995

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
mae=mean_absolute_error(y_test,y_pred_lr)
mae
# Out:
# 3076.023379248111

# %%
mse=mean_squared_error(y_test,y_pred_lr)
mse
# Out:
# 14866177.214236282

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 3855.66819296426

# %% [markdown]
# ## 2nd model Decision tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
#checking training datta score
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
y_pred_dt=dt.predict(x_test)

# %%
dt.score(x_test,y_test)
# Out:
# -0.2069043121452685

# %%
#r2 score
r2_score(y_test,y_pred_dt)
# Out:
# -0.2069043121452685

# %% [markdown]
# ## 3rd Model random forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(x_train,y_train)
# Out:
# 0.9167728585358648

# %%
rf.score(x_test,y_test)
# Out:
# 0.3925724507639462

# %%
y_pred_rf=rf.predict(x_test)

# %%
r2_score(y_test,y_pred_rf)
# Out:
# 0.3925724507639462

# %%
n_estimators=[10,500]
max_features=['auto','sqrt']
max_depth=[2,4]
min_samples_split=[2,4]
min_samples_leaf=[1,2]
bootstrap=[True,False]

# %%
#create the random grid
param_grid={'n_estimators':n_estimators,
           'max_features':max_features,
           'max_depth':max_depth,
           'min_samples_split':min_samples_split,
           'min_samples_leaf':min_samples_leaf,
           'bootstrap':bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [10, 500], 'max_features': ['auto', 'sqrt'], 'max_depth': [2, 4], 'min_samples_split': [2, 4], 'min_samples_leaf': [1, 2], 'bootstrap': [True, False]}

# %%
from sklearn.model_selection import GridSearchCV
rf_grid=GridSearchCV(estimator=rf,param_grid=param_grid,cv=3,verbose=2,n_jobs=4)

# %%
rf_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=4,
#              param_grid={'bootstrap': [True, False], 'max_depth': [2, 4],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 4],
#                          'n_estimators': [10, 500]},
#              verbose=2)

# %%
rf_grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'min_samples_split': 4,
#  'n_estimators': 10}

# %%
rf_grid.score(x_train,y_train)
# Out:
# 0.5922068147616757

# %%
rf_grid.score(x_test,y_pred_rf)
# Out:
# 0.902556796122081

# %%
import pickle

# %%
filename = 'flight_orediction.pkl'
pickle.dump(rf_grid, open(filename, 'wb'))
